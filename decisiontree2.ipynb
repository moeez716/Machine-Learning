# %% [markdown]
# Decision Tree

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

# %%
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#drop deck colomn
df.drop('deck', axis=1, inplace=True)

# %%
#impute missing values
imputer=SimpleImputer(strategy='median')
df[['age','fare']]=imputer.fit_transform(df[['age','fare']])

impute=SimpleImputer(strategy='mode')
df[['embarked','embark_town']]=imputer.fit_transform(df[['age','fare']])

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
#encode the catagorical and object using for loop
label_encoder = LabelEncoder()
for i in df.columns:
    if df[i].dtype == 'object' or df[i].dtype == 'category':
        df[i] = label_encoder.fit_transform(df[i])

# %%
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1  22.0      1      0   7.2500      22.0      2    1
# 1         1       1    0  38.0      1      0  71.2833      38.0      0    2
# 2         1       3    0  26.0      0      0   7.9250      26.0      2    2
# 3         1       1    0  35.0      1      0  53.1000      35.0      0    2
# 4         0       3    1  35.0      0      0   8.0500      35.0      2    1
#
#    adult_male  embark_town  alive  alone
# 0        True       7.2500      0  False
# 1       False      71.2833      1  False
# 2       False       7.9250      1   True
# 3       False      53.1000      1  False
# 4        True       8.0500      0   True

# %%
#split the data
x=df.drop('survived',axis=1)
y=df['survived']

# %%
#train test split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#create and train the model
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
#evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Confusion Matrix:
#  [[105   0]
#  [  0  74]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       105
#            1       1.00      1.00      1.00        74
#
#     accuracy                           1.00       179
#    macro avg       1.00      1.00      1.00       179
# weighted avg       1.00      1.00      1.00       179

# %%
#save the model
from sklearn.tree import export_graphviz
export_graphviz(model,out_file='./saved_models/decisiontree.dot',feature_names=x.columns,filled=True,rounded=True)
